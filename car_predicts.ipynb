# %%
import pandas as pd
import numpy as np

# %%
# predicts car selling_price against how many years it has been used using the categorical features
car = pd.read_csv('car data.csv')
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
car
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
car.shape
# Out:
# (301, 9)

# %%
print(car['Fuel_Type'].unique())
# Out:
# ['Petrol' 'Diesel' 'CNG']

# %%
print(car['Seller_Type'].unique())
# Out:
# ['Dealer' 'Individual']

# %%
print(car['Transmission'].unique())
# Out:
# ['Manual' 'Automatic']

# %%
print(car['Owner'].unique())
# Out:
# [0 1 3]

# %%
car.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
car
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
car.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
final_dataset = car[['Year','Selling_Price', 'Present_Price', 'Kms_Driven',
       'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner']]
final_dataset
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0    2014           3.35           5.59       27000    Petrol      Dealer
# 1    2013           4.75           9.54       43000    Diesel      Dealer
# 2    2017           7.25           9.85        6900    Petrol      Dealer
# 3    2011           2.85           4.15        5200    Petrol      Dealer
# 4    2014           4.60           6.87       42450    Diesel      Dealer
# ..    ...            ...            ...         ...       ...         ...
# 296  2016           9.50          11.60       33988    Diesel      Dealer
# 297  2015           4.00           5.90       60000    Petrol      Dealer
# 298  2009           3.35          11.00       87934    Petrol      Dealer
# 299  2017          11.50          12.50        9000    Diesel      Dealer
# 300  2016           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner
# 0         Manual      0
# 1         Manual      0
# ...

# %%
# final_dataset['current_year'] = 2023
# final_dataset

# %%
no_Year = (2023-car['Year'])
no_Year

# no_Year = final_dataset['current_year'] - final_dataset['Year']
# no_Year
# Out:
# 0       9
# 1      10
# 2       6
# 3      12
# 4       9
#        ..
# 296     7
# 297     8
# 298    14
# 299     6
# 300     7
# Name: Year, Length: 301, dtype: int64

# %%
final_dataset['no_Year'] = no_Year
final_dataset
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0    2014           3.35           5.59       27000    Petrol      Dealer
# 1    2013           4.75           9.54       43000    Diesel      Dealer
# 2    2017           7.25           9.85        6900    Petrol      Dealer
# 3    2011           2.85           4.15        5200    Petrol      Dealer
# 4    2014           4.60           6.87       42450    Diesel      Dealer
# ..    ...            ...            ...         ...       ...         ...
# 296  2016           9.50          11.60       33988    Diesel      Dealer
# 297  2015           4.00           5.90       60000    Petrol      Dealer
# 298  2009           3.35          11.00       87934    Petrol      Dealer
# 299  2017          11.50          12.50        9000    Diesel      Dealer
# 300  2016           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  no_Year
# 0         Manual      0        9
# ...

# %%
final_dataset.drop(['Year'], axis = 1, inplace= True)

# %%
# final_dataset.drop(['current_year'], axis = 1, inplace=True)

# %%
# final_dataset.drop(['Year_2023'], axis = 1, inplace= True)

# %%
final_dataset
# Out:
#      Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0             3.35           5.59       27000    Petrol      Dealer
# 1             4.75           9.54       43000    Diesel      Dealer
# 2             7.25           9.85        6900    Petrol      Dealer
# 3             2.85           4.15        5200    Petrol      Dealer
# 4             4.60           6.87       42450    Diesel      Dealer
# ..             ...            ...         ...       ...         ...
# 296           9.50          11.60       33988    Diesel      Dealer
# 297           4.00           5.90       60000    Petrol      Dealer
# 298           3.35          11.00       87934    Petrol      Dealer
# 299          11.50          12.50        9000    Diesel      Dealer
# 300           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  no_Year
# 0         Manual      0        9
# 1         Manual      0       10
# 2         Manual      0        6
# ...

# %%
final_dataset= pd.get_dummies(final_dataset, drop_first=True)

# %%
final_dataset
# Out:
#      Selling_Price  Present_Price  Kms_Driven  Owner  no_Year  \
# 0             3.35           5.59       27000      0        9
# 1             4.75           9.54       43000      0       10
# 2             7.25           9.85        6900      0        6
# 3             2.85           4.15        5200      0       12
# 4             4.60           6.87       42450      0        9
# ..             ...            ...         ...    ...      ...
# 296           9.50          11.60       33988      0        7
# 297           4.00           5.90       60000      0        8
# 298           3.35          11.00       87934      0       14
# 299          11.50          12.50        9000      0        6
# 300           5.30           5.90        5464      0        7
#
#      Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0                   0                 1                       0
# 1                   1                 0                       0
# ...

# %%
final_dataset.corr()
# Out:
#                         Selling_Price  Present_Price  Kms_Driven     Owner  \
# Selling_Price                1.000000       0.878983    0.029187 -0.088344
# Present_Price                0.878983       1.000000    0.203647  0.008057
# Kms_Driven                   0.029187       0.203647    1.000000  0.089216
# Owner                       -0.088344       0.008057    0.089216  1.000000
# no_Year                     -0.236141       0.047584    0.524342  0.182104
# Fuel_Type_Diesel             0.552339       0.473306    0.172515 -0.053469
# Fuel_Type_Petrol            -0.540571      -0.465244   -0.172874  0.055687
# Seller_Type_Individual      -0.550724      -0.512030   -0.101419  0.124269
# Transmission_Manual         -0.367128      -0.348715   -0.162510 -0.050316
#
#                          no_Year  Fuel_Type_Diesel  Fuel_Type_Petrol  \
# Selling_Price          -0.236141          0.552339         -0.540571
# Present_Price           0.047584          0.473306         -0.465244
# ...

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.pairplot(final_dataset)

# %%
corrmat = final_dataset.corr()
corr_feature = corrmat.index
plt.figure(figsize=(10,10))

#plot heat_map

# g  = sns.heatmap(final_dataset[corr_feature].corr(),annot=True,cmap= 'RdY1Gn')
sns.heatmap(final_dataset[corr_feature].corr(),annot=True, fmt=".1f")

#annot lets see the value(numbers) in the plot
# Out:
# <AxesSubplot:>

# %%
final_dataset.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven  Owner  no_Year  Fuel_Type_Diesel  \
# 0           3.35           5.59       27000      0        9                 0
# 1           4.75           9.54       43000      0       10                 1
# 2           7.25           9.85        6900      0        6                 0
# 3           2.85           4.15        5200      0       12                 0
# 4           4.60           6.87       42450      0        9                 1
#
#    Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# 0                 1                       0                    1
# 1                 0                       0                    1
# 2                 1                       0                    1
# 3                 1                       0                    1
# 4                 0                       0                    1

# %%
#independent x and dependent (y) features
x = final_dataset.drop('Selling_Price', axis=1)
x
# Out:
#      Present_Price  Kms_Driven  Owner  no_Year  Fuel_Type_Diesel  \
# 0             5.59       27000      0        9                 0
# 1             9.54       43000      0       10                 1
# 2             9.85        6900      0        6                 0
# 3             4.15        5200      0       12                 0
# 4             6.87       42450      0        9                 1
# ..             ...         ...    ...      ...               ...
# 296          11.60       33988      0        7                 1
# 297           5.90       60000      0        8                 0
# 298          11.00       87934      0       14                 0
# 299          12.50        9000      0        6                 1
# 300           5.90        5464      0        7                 0
#
#      Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# 0                   1                       0                    1
# ...

# %%
y = final_dataset['Selling_Price']
y
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: Selling_Price, Length: 301, dtype: float64

# %%
# final_dataset.iloc[:,0]

# %%
# feature importance
from sklearn.ensemble import ExtraTreesRegressor

# %%
model = ExtraTreesRegressor()

# %%
model.fit(x,y)
# Out:
# ExtraTreesRegressor()

# %%
print(model.feature_importances_)
# Out:
# [0.3984502  0.0436717  0.00041682 0.07268577 0.2271401  0.01644742
#  0.10786864 0.13331933]

# %%
x
# Out:
#      Present_Price  Kms_Driven  Owner  no_Year  Fuel_Type_Diesel  \
# 0             5.59       27000      0        9                 0
# 1             9.54       43000      0       10                 1
# 2             9.85        6900      0        6                 0
# 3             4.15        5200      0       12                 0
# 4             6.87       42450      0        9                 1
# ..             ...         ...    ...      ...               ...
# 296          11.60       33988      0        7                 1
# 297           5.90       60000      0        8                 0
# 298          11.00       87934      0       14                 0
# 299          12.50        9000      0        6                 1
# 300           5.90        5464      0        7                 0
#
#      Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# 0                   1                       0                    1
# ...

# %%
feature_import = pd.Series(model.feature_importances_,index=x.columns)
feature_import.nlargest(5).plot(kind='barh')
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test,y_train, y_test = train_test_split(x,y, test_size=0.2)

# %%
x_train
# Out:
#      Present_Price  Kms_Driven  Owner  no_Year  Fuel_Type_Diesel  \
# 265           8.70       21200      0        6                 0
# 173           0.51        1300      0        6                 0
# 249           7.60       17000      0        7                 0
# 166           0.55        1000      0        7                 0
# 191           0.57       25000      1       11                 0
# ..             ...         ...    ...      ...               ...
# 92           13.70       75000      0       18                 0
# 89            6.76       40000      0        9                 0
# 117           1.90       14000      0        8                 0
# 242           7.13       34000      0        9                 0
# 67           20.45       59000      0       13                 1
#
#      Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# 265                 1                       0                    1
# ...

# %%
x_test.shape
# Out:
# (61, 8)

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor()

# %%
# Hyperparameters

#Number of trees in RandomForest
n_estimators = [int(x)
                for x in np.linspace
                (start=100, stop= 120, num=12)]
print(n_estimators)

#Number of max no of feature to consider at every split
max_features = ['auto', 'sqrt']
print(max_features)

#max No of level in Trees
max_depth = [int(x)
                for x in np.linspace
                (5,30 , num=12)]
#max depth append.none
print(max_depth)

#min no of samples required to split a node
min_samples_split = [2,5,10, 15, 100]
print(min_samples_split)

#min no of samples required to at each leaf node
min_samples_leaf = [1, 2,5,10]
print(min_samples_leaf)
# Out:
# [100, 101, 103, 105, 107, 109, 110, 112, 114, 116, 118, 120]
# ['auto', 'sqrt']
# [5, 7, 9, 11, 14, 16, 18, 20, 23, 25, 27, 30]
# [2, 5, 10, 15, 100]
# [1, 2, 5, 10]

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
random_grid = {
    'n_estimators':n_estimators,
    'max_features': max_features,
    'max_depth':max_depth,
    'min_samples_split': min_samples_split,
    'min_samples_leaf':min_samples_leaf
}

print(random_grid)
# Out:
# {'n_estimators': [100, 101, 103, 105, 107, 109, 110, 112, 114, 116, 118, 120], 'max_features': ['auto', 'sqrt'], 'max_depth': [5, 7, 9, 11, 14, 16, 18, 20, 23, 25, 27, 30], 'min_samples_split': [2, 5, 10, 15, 100], 'min_samples_leaf': [1, 2, 5, 10]}

# %%
#use RandonForestRegressor to search for best hyper_parameter

rfr = RandomForestRegressor()

# %%
rfr_random = RandomizedSearchCV(estimator = rfr,
                         param_distributions = random_grid,scoring='neg_mean_squared_error', 
                         n_iter = 10, cv= 5, verbose=2, random_state=42, n_jobs=1)

# %%
rfr_random.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END max_depth=7, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=114; total time=   0.1s
# [CV] END max_depth=7, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=114; total time=   0.1s
# [CV] END max_depth=7, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=114; total time=   0.1s
# [CV] END max_depth=7, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=114; total time=   0.1s
# [CV] END max_depth=7, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=114; total time=   0.1s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=2, min_samples_split=100, n_estimators=103; total time=   0.1s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=2, min_samples_split=100, n_estimators=103; total time=   0.1s
# ...

# %%
prediction = rfr_random.predict(x_test)
prediction
# Out:
# array([ 9.57949496,  5.41277731,  8.97118596, 19.99232163, 10.57880609,
#         8.93963439,  7.64594982,  6.14602553,  5.35943462,  4.45740927,
#         5.43642881,  7.18993719,  1.20554819,  3.20318114,  1.19819546,
#         5.18770138,  5.66929044,  0.25180981, 19.95928843,  0.39879447,
#         0.37008447,  3.93514061,  5.28755395,  0.62258905,  0.63836752,
#        19.95928843, 19.95928843,  4.91716143,  0.5414551 ,  1.14003825,
#         0.47737657, 10.18545905,  5.76770969,  9.59797377,  3.94080704,
#        10.31956948,  5.51366506,  4.32697257, 19.99232163,  5.22451985,
#         1.16111909, 13.25327045, 17.48295534,  7.89217266, 10.31956948,
#         5.04873271,  3.14753576,  5.43642881,  5.58954127,  7.29502832,
#         6.71774041, 10.65551156,  5.11228018,  4.87993169,  4.69579776,
#         5.46509222,  6.67927005,  1.92940854,  7.27654951,  0.50996236,
#         2.85914322])

# %%
sns.displot(y_test-prediction)

# %%
plt.scatter(y_test,prediction)

# %%
import pickle

# %%
#create a pickle file to save the model
File = open('rfr_model.pkl', 'wb')

#dump the info in the file

pickle.dump(rfr_random, File)
